# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Data Transformation
#
# We need our data to look something like this for py-irt
#
# ```json
# {"subject_id": "pedro",    "responses": {"q1": 1, "q2": 0, "q3": 1, "q4": 0}}
# {"subject_id": "pinguino", "responses": {"q1": 1, "q2": 1, "q3": 0, "q4": 0}}
# {"subject_id": "ken",      "responses": {"q1": 1, "q2": 1, "q3": 1, "q4": 1}}
# {"subject_id": "burt",     "responses": {"q1": 0, "q2": 0, "q3": 0, "q4":
# ```
#
#
# ## Setup
#
# ```
# conda create -n ENVNAME python=3.10 pandas
# conda activate ENVNAME
# ```
#
# ```
# conda install -c conda-forge jupyterlab
# pip install py-irt
# ```0}}

# %%
import pandas as pd
import json

# %%
# !pip install pyro-ppl
# !pip install py-irt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 732.8/732.8 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 56.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 66.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 70.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 MB 1.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 kB 36.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 62.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 1.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 53.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
# ...

# %%
# !pwd
# %cd /content/drive/MyDrive/py_irt
# Out:
# /content
# /content/drive/MyDrive/py_irt

# %%
tasks=["mnli","mrpc","qnli","qqp","rte","sst2"]
for task in tasks:
    # !py-irt train 1pl {task}_pyirt.jsonlines {task}1pl
# Out:
# Streaming output truncated to the last 5000 lines.
# │ 1     │ 268944960.0000 │ 268944960.0000 │ 0.1000 │
# │ 101   │ 9275146.3356   │ 9238200.0375   │ 0.0990 │
# │ 201   │ 3490821.5438   │ 3490821.5438   │ 0.0980 │
# │ 301   │ 2366161.1019   │ 2366161.1019   │ 0.0970 │
# │ 401   │ 1806412.3129   │ 1796341.1599   │ 0.0961 │
# │ 501   │ 1467436.3414   │ 1467436.3414   │ 0.0951 │
# │ 601   │ 1259528.2691   │ 1259528.2691   │ 0.0942 │
# │ 701   │ 1119314.2762   │ 1119314.2762   │ 0.0932 │
# │ 801   │ 1014524.1714   │ 1014524.1714   │ 0.0923 │
# │ 901   │ 949578.0908    │ 948395.5634    │ 0.0914 │
# ┏━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━┓
# ┃ Epoch ┃ Loss           ┃ Best Loss      ┃ New LR ┃
# ┡━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━┩
# │ 1     │ 268944960.0000 │ 268944960.0000 │ 0.1000 │
# │ 101   │ 9275146.3356   │ 9238200.0375   │ 0.0990 │
# │ 201   │ 3490821.5438   │ 3490821.5438   │ 0.0980 │
# │ 301   │ 2366161.1019   │ 2366161.1019   │ 0.0970 │
# ...

# %% [markdown]
# For the next block, use either
#
# ```
# !cat output/cola1pl/best_parameters.json
# ```
#
# or
#
# ```
# !type output\cola1pl\best_parameters.json
# ```
#
# depending on your operating system.

# %%
# !cat "mnli1pl/best_parameters.json"
# Out:
# {"ability": [-1.5956090688705444, 1.1129279136657715, 0.8522819876670837, -1.1628888845443726, 0.63353031873703, 1.5661507844924927, 0.6774624586105347, 1.3918424844741821, 1.2589961290359497, 1.201259970664978], "diff": [-0.07800032943487167, -4.398254871368408, 0.5658080577850342, -1.1409903764724731, 0.28216415643692017, -0.035008497536182404, -0.3313016891479492, 2.103715419769287, 0.8292329907417297, 0.8537081480026245, -0.44012847542762756, 0.015937604010105133, 1.2777115106582642, -1.7697662115097046, 1.209252119064331, 0.964453399181366, 0.711654782295227, -1.55133056640625, 0.08537048101425171, -2.6325604915618896, -0.5331456065177917, 0.2199031114578247, -0.2707676589488983, -0.13810807466506958, -0.32979655265808105, 0.2525072693824768, 1.1890811920166016, 0.5751138925552368, -1.5175871849060059, -1.2848730087280273, -1.445273518562317, 0.33388659358024597, 0.6246867775917053, 0.6081891655921936, -1.3025683164596558, 0.3595409095287323, -0.23426800966262817, 0.171019822359
# ...

# %%
for task in tasks:
    print(task)
    with open (f"{task}1pl/best_parameters.json","r") as file:
        data = json.load(file)
        print(task)
        print(data.keys())
# Out:
# mnli
# mnli
# dict_keys(['ability', 'diff', 'irt_model', 'item_ids', 'subject_ids'])
# mrpc
# mrpc
# dict_keys(['ability', 'diff', 'irt_model', 'item_ids', 'subject_ids'])
# qnli
# qnli
# dict_keys(['ability', 'diff', 'irt_model', 'item_ids', 'subject_ids'])
# qqp
# qqp
# dict_keys(['ability', 'diff', 'irt_model', 'item_ids', 'subject_ids'])
# rte
# rte
# dict_keys(['ability', 'diff', 'irt_model', 'item_ids', 'subject_ids'])
# sst2
# sst2
# dict_keys(['ability', 'diff', 'irt_model', 'item_ids', 'subject_ids'])

# %%
for task in tasks:
    with open (f"{task}1pl/best_parameters.json","r") as file:
        data = json.load(file)
        print(task)
        print(data["ability"])
        print(data["subject_ids"])
        print("========")
# Out:
# mnli
# [-1.5956090688705444, 1.1129279136657715, 0.8522819876670837, -1.1628888845443726, 0.63353031873703, 1.5661507844924927, 0.6774624586105347, 1.3918424844741821, 1.2589961290359497, 1.201259970664978]
# {'0': 'albert-base-v2_128', '1': 'bart-base_128', '2': 'bert-base-uncased_128', '3': 'deberta-base_128', '4': 'distilbert-base-uncased_128', '5': 'electra-base-discriminator_128', '6': 'gpt2_128', '7': 'roberta-base_128', '8': 't5-base_128', '9': 'xlnet-base-cased_128'}
# ...
# mrpc
# [0.4930720627307892, 0.7640931606292725, 0.48163169622421265, 0.6205850839614868, 0.5787466764450073, 1.0452932119369507, 0.3252410888671875, 0.5240991711616516, 0.4952540099620819, 0.8011143207550049]
# {'0': 'albert-base-v2_128', '1': 'bart-base_128', '2': 'bert-base-uncased_128', '3': 'deberta-base_128', '4': 'distilbert-base-uncased_128', '5': 'electra-base-discriminator_128', '6': 'gpt2_128', '7': 'roberta-base_128', '8': 't5-base_128', '9': 'xlnet-base-cased_128'}
# ...
# qnli
# ...

# %%
print(max(data["diff"]))
print(min(data["diff"]))
# Out:
# 4.645705699920654
# -31.083784103393555

# %%
print(data["ability"])
# Out:
# [2.4077541828155518, 3.0727083683013916, 3.1854166984558105, 2.652914047241211, 3.1306893825531006, 3.426816940307617, 2.4763715267181396, 3.5202982425689697, 2.824596405029297, 2.9875078201293945]

# %%
print(data["subject_ids"])
# Out:
# {'0': 'albert-base-v2_128', '1': 'bart-base_128', '2': 'bert-base-uncased_128', '3': 'deberta-base_128', '4': 'distilbert-base-uncased_128', '5': 'electra-base-discriminator_128', '6': 'gpt2_128', '7': 'roberta-base_128', '8': 't5-base_128', '9': 'xlnet-base-cased_128'}

# %%
print(data['irt_model'])
# Out:
# 1pl
